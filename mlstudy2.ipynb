# %% [markdown]
# <a href="https://colab.research.google.com/github/erica00j/machinelearning/blob/main/mlstudy2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/listings_berlin.csv')
df.head()
# Out:
#      id                                               name  host_id host_name  \
# 0  1944         bright & airy Pberg/Mitte 3 months or more     2164     Lulah
# 1  2015   Berlin-Mitte Value! Quiet courtyard/very central     2217       Ion
# 2  3176                    Fabulous Flat in great Location     3718    Britta
# 3  3309                  BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  6883  Stylish East Side Loft in Center with AC & 2 b...    16149   Steffen
#
#         neighbourhood_group             neighbourhood  latitude  longitude  \
# 0                     Mitte          Brunnenstr. Nord  52.54433   13.39761
# 1                     Mitte           Brunnenstr. Süd  52.53305   13.40394
# 2                    Pankow   Prenzlauer Berg Südwest  52.53471   13.41810
# 3    Tempelhof - Schöneberg           Schöneberg-Nord  52.49884   13.34940
# 4  Friedrichshain-Kreuzberg  Frankfurter Allee Süd FK  52.51163   13.45289
#
# ...

# %% [markdown]
# https://www.kaggle.com/datasets/lennarthaupts/airbnb-berlin-july-2021

# %%
df.shape
# Out:
# (19095, 16)

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                30
# host_id                              0
# host_name                           12
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       4155
# reviews_per_month                 4155
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %% [markdown]
# df.isnull().sum()은 각 컬럼별 결측치(missing value)가 몇개 있는지 확인

# %%
df = pd.get_dummies(df, columns = ['neighbourhood_group', 'neighbourhood'])
df.head()
# Out:
#      id                                               name  host_id host_name  \
# 0  1944         bright & airy Pberg/Mitte 3 months or more     2164     Lulah
# 1  2015   Berlin-Mitte Value! Quiet courtyard/very central     2217       Ion
# 2  3176                    Fabulous Flat in great Location     3718    Britta
# 3  3309                  BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  6883  Stylish East Side Loft in Center with AC & 2 b...    16149   Steffen
#
#    latitude  longitude        room_type  price  minimum_nights  \
# 0  52.54433   13.39761     Private room     28              60
# 1  52.53305   13.40394  Entire home/apt     74              90
# 2  52.53471   13.41810  Entire home/apt     90              62
# 3  52.49884   13.34940     Private room     29               7
# 4  52.51163   13.45289  Entire home/apt     79               7
#
#    number_of_reviews  ... neighbourhood_West 3  neighbourhood_West 4  \
# ...

# %% [markdown]
# pd.get_dummies()는 더미의 가변수를 만들 수 있는 함수

# %%
del df['latitude']

# %%
del df['longitude']

# %%
df.shape
# Out:
# (19095, 162)

# %%
df.head()
# Out:
#      id                                               name  host_id host_name  \
# 0  1944         bright & airy Pberg/Mitte 3 months or more     2164     Lulah
# 1  2015   Berlin-Mitte Value! Quiet courtyard/very central     2217       Ion
# 2  3176                    Fabulous Flat in great Location     3718    Britta
# 3  3309                  BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  6883  Stylish East Side Loft in Center with AC & 2 b...    16149   Steffen
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     28              60                 18  2018-11-11
# 1  Entire home/apt     74              90                141  2020-04-03
# 2  Entire home/apt     90              62                147  2017-03-20
# 3     Private room     29               7                 27  2018-08-16
# 4  Entire home/apt     79               7                135  2021-01-02
#
# ...

# %%
df.isnull().sum()
# Out:
# id                                      0
# name                                   30
# host_id                                 0
# host_name                              12
# room_type                               0
#                                        ..
# neighbourhood_Wilhelmstadt              0
# neighbourhood_Zehlendorf  Nord          0
# neighbourhood_Zehlendorf  Südwest       0
# neighbourhood_nördliche Luisenstadt     0
# neighbourhood_südliche Luisenstadt      0
# Length: 162, dtype: int64
